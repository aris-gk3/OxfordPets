# %%
from ml_project_util.load_preprocess import test_split, undo_test_split

# %%
undo_test_split()
# Out:
# *** Training & Validation Classes are:
#
# 0. Abyssinian (183 images)
# 1. American_Bulldog (180 images)
# 2. American_Pitbull (180 images)
# 3. Basset_Hound (180 images)
# 4. Beagle (180 images)
# 5. Bengal (180 images)
# 6. Birman (180 images)
# 7. Bombay (180 images)
# 8. Boxer (180 images)
# 9. British_Shorthair (180 images)
# 10. Cihuahua (180 images)
# 11. Egyptian_Mau (180 images)
# 12. English_Cocker (180 images)
# 13. English_Setter (180 images)
# 14. German_Shorthaired (180 images)
# 15. Great_Pyrenees (180 images)
# 16. Havanese (180 images)
# 17. Japanese_Chin (180 images)
# 18. Keeshond (180 images)
# 19. Leonberger (180 images)
# 20. Maine_Coon (180 images)
# 21. Miniature_Pinsche (180 images)
# 22. Newfoundland (180 images)
# 23. Persian (180 images)
# 24. Pomeranian (180 images)
# 25. Pug (180 images)
# 26. Ragdoll (180 images)
# 27. Russian_Blue (180 images)
# 28. Saint_Bernard (180 images)
# 29. Samoyed (180 images)
# 30. Scottish_Terrier (180 images)
# ...

# %%
test_split(percent=10, verbose=1)
# Out:
# *** Training & Validation Classes are:
#
# 0. Abyssinian (203 images)
# 1. American_Bulldog (200 images)
# 2. American_Pitbull (200 images)
# 3. Basset_Hound (200 images)
# 4. Beagle (200 images)
# 5. Bengal (200 images)
# 6. Birman (200 images)
# 7. Bombay (200 images)
# 8. Boxer (200 images)
# 9. British_Shorthair (200 images)
# 10. Cihuahua (200 images)
# 11. Egyptian_Mau (200 images)
# 12. English_Cocker (200 images)
# 13. English_Setter (200 images)
# 14. German_Shorthaired (200 images)
# 15. Great_Pyrenees (200 images)
# 16. Havanese (200 images)
# 17. Japanese_Chin (200 images)
# 18. Keeshond (200 images)
# 19. Leonberger (200 images)
# 20. Maine_Coon (200 images)
# 21. Miniature_Pinsche (200 images)
# 22. Newfoundland (200 images)
# 23. Persian (200 images)
# 24. Pomeranian (200 images)
# 25. Pug (200 images)
# 26. Ragdoll (200 images)
# 27. Russian_Blue (200 images)
# 28. Saint_Bernard (200 images)
# 29. Samoyed (200 images)
# 30. Scottish_Terrier (199 images)
# ...
